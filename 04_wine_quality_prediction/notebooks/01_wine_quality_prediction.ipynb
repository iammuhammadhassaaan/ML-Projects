# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # **Wine Quality Dataset**
#
# **👨‍💻Author: Muhammad Hassaan**
#
# [![GitHub](https://img.shields.io/badge/GitHub-Profile-blue?style=for-the-badge&logo=github)](https://github.com/iammuhammadhassaaan)
# [![Kaggle](https://img.shields.io/badge/Kaggle-Profile-blue?style=for-the-badge&logo=kaggle)](https://www.kaggle.com/mhassaan1122)
# [![LinkedIn](https://img.shields.io/badge/LinkedIn-Profile-blue?style=for-the-badge&logo=linkedin)](https://www.linkedin.com/in/iammuhammadhassaan7/)
# [![Email](https://img.shields.io/badge/Email-Contact%20Me-red?style=for-the-badge&logo=email)](mailto:muhammadhassaan7896@gmail.com)

# %% [markdown]
# ## **Meta Data of Wine Quality Dataset**:
#
# The **Wine Quality Dataset** contains physicochemical inputs and sensory-based output data for various wine samples. Input variables, such as **fixed acidity**, **volatile acidity**, and **alcohol content**, are measured through laboratory tests to determine the chemical composition of the wine.
#
# These features directly influence the wine's overall flavor and quality. The output variable, **quality**, is scored based on sensory evaluations by wine experts, ranging from 0 to 10. This dataset is often used for machine learning tasks like regression and classification.
#
# ### Input Variables (Physicochemical Tests):
# 1. **Fixed Acidity**:
#    - **Description**: The non-volatile acids present in the wine, such as tartaric acid.
#    - **Type**: Numeric (Continuous)
#    - **Units**: g/dm³
#    - **Range**: Typically between 4 and 16.
#
# 2. **Volatile Acidity**:
#    - **Description**: The amount of acetic acid in the wine, which at too high levels can lead to an unpleasant vinegar taste.
#    - **Type**: Numeric (Continuous)
#    - **Units**: g/dm³
#    - **Range**: Generally between 0.1 and 1.5.
#
# 3. **Citric Acid**:
#    - **Description**: A weak organic acid found in citrus fruits; adds freshness and flavor.
#    - **Type**: Numeric (Continuous)
#    - **Units**: g/dm³
#    - **Range**: Usually between 0 and 1.
#
# 4. **Residual Sugar**:
#    - **Description**: The amount of sugar remaining after fermentation stops. Wines with higher residual sugar tend to be sweeter.
#    - **Type**: Numeric (Continuous)
#    - **Units**: g/dm³
#    - **Range**: Can vary widely; most wines fall between 0.5 and 20 g/dm³.
#
# 5. **Chlorides**:
#    - **Description**: The amount of salt in the wine, affecting taste and stability.
#    - **Type**: Numeric (Continuous)
#    - **Units**: g/dm³
#    - **Range**: Generally between 0.01 and 0.2.
#
# 6. **Free Sulfur Dioxide**:
#    - **Description**: The amount of SO2 that is not bound and remains in the wine as free molecules. This component helps prevent microbial growth and oxidation.
#    - **Type**: Numeric (Continuous)
#    - **Units**: mg/dm³
#    - **Range**: Typically between 1 and 72.
#
# 7. **Total Sulfur Dioxide**:
#    - **Description**: The total amount of SO2, both free and bound, used as a preservative.
#    - **Type**: Numeric (Continuous)
#    - **Units**: mg/dm³
#    - **Range**: Commonly between 6 and 289.
#
# 8. **Density**:
#    - **Description**: The density of the wine, influenced by the alcohol and sugar content.
#    - **Type**: Numeric (Continuous)
#    - **Units**: g/cm³
#    - **Range**: Varies from 0.990 to 1.003.
#
# 9. **pH**:
#    - **Description**: A measure of acidity or alkalinity of the wine.
#    - **Type**: Numeric (Continuous)
#    - **Units**: N/A (pH scale)
#    - **Range**: Usually between 2.8 and 3.8.
#
# 10. **Sulphates**:
#    - **Description**: A wine additive that can contribute to SO2 levels and acts as an antimicrobial and antioxidant.
#    - **Type**: Numeric (Continuous)
#    - **Units**: g/dm³
#    - **Range**: Generally from 0.3 to 1.
#
# 11. **Alcohol**:
#    - **Description**: The percentage of alcohol content in the wine.
#    - **Type**: Numeric (Continuous)
#    - **Units**: %
#    - **Range**: Typically between 8 and 15%.
#
# ### Output Variable (Sensory Data):
# 12. **Quality**:
#    - **Description**: The quality of the wine, based on sensory evaluation by wine experts, scored on a scale from 0 (worst) to 10 (best).
#    - **Type**: Numeric (Discrete)
#    - **Units**: Score
#    - **Range**: 0 to 10, although most scores range between 3 and 8.
#
# Explore more about the dataset [here](https://www.kaggle.com/datasets/yasserh/wine-quality-dataset).

# %% [markdown]
# ---

# %% [markdown]
# ## Import Libraries

# %%
# import libraries 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
import plotly.subplots as sp
from scipy.stats import chi2
import statsmodels.api as sm

# import sklearn modules for machine learning
from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV, cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler, LabelEncoder, OneHotEncoder, PolynomialFeatures

# import warnings
import warnings
warnings.filterwarnings('ignore')

# display all columns and rows
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# for saving models
import joblib
import pickle

# %% [markdown]
# ## Load the Data

# %%
# load the dataset
df = pd.read_csv("../data/WineQT.csv")

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### 1. Basic Exploration

# %%
# show the head of the dataset
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  Id
# 0      9.4        5   0
# 1      9.8        5   1
# ...

# %%
# show the tail of the dataset
df.tail()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1138                 29.0                  40.0  0.99574  3.42       0.75
# 1139                 28.0                  38.0  0.99651  3.42       0.82
# 1140                 32.0                  44.0  0.99490  3.45       0.58
# 1141                 39.0                  51.0  0.99512  3.52       0.76
# 1142                 32.0                  44.0  0.99547  3.57       0.71
#
#       alcohol  quality    Id
# ...

# %%
# check the shape of the dataset
df.shape
# Out:
# (1143, 13)

# %%
# check info of the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1143 entries, 0 to 1142
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1143 non-null   float64
#  1   volatile acidity      1143 non-null   float64
#  2   citric acid           1143 non-null   float64
#  3   residual sugar        1143 non-null   float64
#  4   chlorides             1143 non-null   float64
#  5   free sulfur dioxide   1143 non-null   float64
#  6   total sulfur dioxide  1143 non-null   float64
#  7   density               1143 non-null   float64
#  8   pH                    1143 non-null   float64
#  9   sulphates             1143 non-null   float64
#  10  alcohol               1143 non-null   float64
#  11  quality               1143 non-null   int64
#  12  Id                    1143 non-null   int64
# dtypes: float64(11), int64(2)
# memory usage: 116.2 KB

# %%
# check summary statistics of the data
df.describe().T
# Out:
#                        count        mean         std      min        25%  \
# fixed acidity         1143.0    8.311111    1.747595  4.60000    7.10000
# volatile acidity      1143.0    0.531339    0.179633  0.12000    0.39250
# citric acid           1143.0    0.268364    0.196686  0.00000    0.09000
# residual sugar        1143.0    2.532152    1.355917  0.90000    1.90000
# chlorides             1143.0    0.086933    0.047267  0.01200    0.07000
# free sulfur dioxide   1143.0   15.615486   10.250486  1.00000    7.00000
# total sulfur dioxide  1143.0   45.914698   32.782130  6.00000   21.00000
# density               1143.0    0.996730    0.001925  0.99007    0.99557
# pH                    1143.0    3.311015    0.156664  2.74000    3.20500
# sulphates             1143.0    0.657708    0.170399  0.33000    0.55000
# alcohol               1143.0   10.442111    1.082196  8.40000    9.50000
# quality               1143.0    5.657043    0.805824  3.00000    5.00000
# ...

# %%
# corr of the data
df.corr().T
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.250728     0.673157
# volatile acidity          -0.250728          1.000000    -0.544187
# citric acid                0.673157         -0.544187     1.000000
# residual sugar             0.171831         -0.005751     0.175815
# chlorides                  0.107889          0.056336     0.245312
# free sulfur dioxide       -0.164831         -0.001962    -0.057589
# total sulfur dioxide      -0.110628          0.077748     0.036871
# density                    0.681501          0.016512     0.375243
# pH                        -0.685163          0.221492    -0.546339
# sulphates                  0.174592         -0.276079     0.331232
# alcohol                   -0.075055         -0.203909     0.106250
# quality                    0.121970         -0.407394     0.240821
# Id                        -0.275826         -0.007892    -0.139011
#
# ...

# %%
# check the datatypes of the data
df.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# Id                        int64
# dtype: object

# %%
# check null values
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# Id                      0
# dtype: int64

# %%
# check quantile
df.quantile([0, 0.05, 0.25, 0.50, 0.75, 0.99, 1]).T
# Out:
#                          0.00       0.05       0.25       0.50         0.75  \
# fixed acidity         4.60000   6.100000    7.10000    7.90000     9.100000
# volatile acidity      0.12000   0.271000    0.39250    0.52000     0.640000
# citric acid           0.00000   0.000000    0.09000    0.25000     0.420000
# residual sugar        0.90000   1.600000    1.90000    2.20000     2.600000
# chlorides             0.01200   0.054000    0.07000    0.07900     0.090000
# free sulfur dioxide   1.00000   4.000000    7.00000   13.00000    21.000000
# total sulfur dioxide  6.00000  12.000000   21.00000   37.00000    61.000000
# density               0.99007   0.993602    0.99557    0.99668     0.997845
# pH                    2.74000   3.070000    3.20500    3.31000     3.400000
# sulphates             0.33000   0.470000    0.55000    0.62000     0.730000
# alcohol               8.40000   9.200000    9.50000   10.20000    11.100000
# ...

# %% [markdown]
# ### 2. Outlier Detection

# %% [markdown]
# #### 2.1 Boxplot Visualization for Outlier Detection

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality', 'Id'],
#       dtype='object')

# %%
# plot boxplots for each numeric feature to visually identity coutliers
numeric_features = ['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar', 'chlorides', 'free sulfur dioxide','total sulfur dioxide', 'density',
       'pH', 'sulphates', 'alcohol']

# plotting through seaborn
plt.figure(figsize=(15, 10))
for i, feature in enumerate(numeric_features, 1):
    plt.subplot(5, 5, i)  # Adjust subplot grid size based on the number of features
    sns.boxplot(x=df[feature])
    plt.title(f'Boxplot of {feature}')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### 2.2 Interquartile Range (IQR) Method for Outlier Detection

# %%
# funtion to detect outliers based on IQR 
def detect_outliers(df, features):
    Q1 = df[features].quantile(0.25)
    Q3 = df[features].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = df[(df[features] < lower_bound) | (df[features] > upper_bound)]
    return outliers

# applyint the IQR method to all numeric features
for feature in numeric_features:
    outliers = detect_outliers(df, feature)
    print(f"Outliers detected in {feature} using IQR: {len(outliers)}")
    print(outliers)
    print()
# Out:
# Outliers detected in fixed acidity using IQR: 44
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 145           12.8             0.300         0.74             2.6      0.095
# 146           12.8             0.300         0.74             2.6      0.095
# 170           15.0             0.210         0.44             2.2      0.075
# 171           15.0             0.210         0.44             2.2      0.075
# 188           12.5             0.560         0.49             2.4      0.064
# 211           13.3             0.340         0.52             3.2      0.094
# 234           13.4             0.270         0.62             2.6      0.082
# 240           12.5             0.280         0.54             2.3      0.082
# 244           13.8             0.490         0.67             3.0      0.093
# 248           13.5             0.530         0.79             4.8      0.120
# ...

# %% [markdown]
# #### 2.3 Z-Score Method for Outlier Detection

# %%
# fucntion to detect outliers based on z-score
def detect_outliers_zscore(df, features):
    outliers = []
    threshold = 3
    mean = np.mean(df[features])
    std = np.std(df[features])
    for i in df.index:
        z_score = (df.loc[i, features] - mean) / std
        if np.abs(z_score) > threshold:
            outliers.append(i)
    return outliers

# applying the z-score method to all numeric features
for feature in numeric_features:
    outliers = detect_outliers_zscore(df, feature)
    print(f"Outliers detected in {feature} using z-score: {len(outliers)}")
    print(outliers)
    print()
# Out:
# Outliers detected in fixed acidity using z-score: 9
# [170, 171, 244, 272, 311, 388, 397, 399, 462]
#
# Outliers detected in volatile acidity using z-score: 5
# [87, 88, 142, 922, 931]
#
# Outliers detected in citric acid using z-score: 1
# [103]
#
# Outliers detected in residual sugar using z-score: 23
# [114, 115, 230, 231, 275, 278, 287, 289, 339, 348, 424, 460, 462, 627, 644, 648, 756, 760, 761, 1022, 1051, 1053, 1111]
#
# Outliers detected in chlorides using z-score: 21
# [13, 30, 75, 103, 129, 161, 167, 182, 200, 407, 490, 520, 538, 557, 738, 890, 934, 973, 975, 1111, 1122]
#
# Outliers detected in free sulfur dioxide using z-score: 13
# [275, 278, 654, 655, 690, 831, 871, 919, 965, 1022, 1051, 1053, 1111]
#
# Outliers detected in total sulfur dioxide using z-score: 10
# [249, 366, 421, 452, 453, 460, 485, 760, 761, 1066]
#
# Outliers detected in density using z-score: 12
# [311, 339, 397, 399, 430, 597, 598, 627, 714, 787, 898, 1022]
#
# ...

# %% [markdown]
# ### 3. Feature Engineering

# %% [markdown]
# #### 3.1 Interaction Terms

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality', 'Id'],
#       dtype='object')

# %%
# creating new terms by multiplying existing features
df['pH_alcohol'] = df['pH'] * df['alcohol']
df['acidity_sulphates'] = df['fixed acidity'] * df['sulphates']

# checkinh correlation after creating new features
interaction_features = ['pH_alcohol', 'acidity_sulphates']

plt.figure(figsize=(8, 6))
sns.heatmap(df[interaction_features].corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# #### 3.2 Feature Scaling

# %%
# normalizing and standardizing teh features for consistent scaling
scaler = StandardScaler()
df_scaled = scaler.fit_transform(df.drop(columns=['quality']))

# %%
# creating a new dataframe with scaled features
df_scaled = pd.DataFrame(df_scaled, columns=df.drop(columns=['quality']).columns)
df_scaled.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0      -0.521580          0.939332    -1.365027       -0.466421  -0.231395
# 1      -0.292593          1.941813    -1.365027        0.050060   0.234247
# 2      -0.292593          1.273492    -1.161568       -0.171289   0.107253
# 3       1.653789         -1.399789     1.483400       -0.466421  -0.252560
# 4      -0.521580          0.939332    -1.365027       -0.466421  -0.231395
#
#    free sulfur dioxide  total sulfur dioxide   density        pH  sulphates  \
# 0            -0.450467             -0.363610  0.555854  1.270695  -0.573658
# 1             0.915920              0.643477  0.036165 -0.708928   0.130881
# 2            -0.060071              0.246745  0.140103 -0.325775  -0.045254
# 3             0.135127              0.429852  0.659792 -0.964363  -0.456235
# 4            -0.450467             -0.363610  0.555854  1.270695  -0.573658
#
#     alcohol        Id  pH_alcohol  acidity_sulphates
# ...

# %%
# check summary statistics of the data
df_scaled.describe().T
# Out:
#                        count          mean       std       min       25%  \
# fixed acidity         1143.0 -3.729883e-16  1.000438 -2.124483 -0.693319
# volatile acidity      1143.0  4.475860e-16  1.000438 -2.290883 -0.773239
# citric acid           1143.0  2.486589e-17  1.000438 -1.365027 -0.907244
# residual sugar        1143.0  1.554118e-16  1.000438 -1.204252 -0.466421
# chlorides             1143.0  8.081413e-17  1.000438 -1.585988 -0.358388
# free sulfur dioxide   1143.0 -5.594825e-17  1.000438 -1.426458 -0.840863
# total sulfur dioxide  1143.0  9.946355e-17  1.000438 -1.218108 -0.760341
# density               1143.0  5.783805e-14  1.000438 -3.461348 -0.603054
# pH                    1143.0 -8.454402e-16  1.000438 -3.646432 -0.676998
# sulphates             1143.0  4.973178e-17  1.000438 -1.924024 -0.632369
# alcohol               1143.0 -1.193563e-15  1.000438 -1.887834 -0.870937
# Id                    1143.0  0.000000e+00  1.000438 -1.735618 -0.849449
# ...

# %% [markdown]
# #### 3.3 Polynomial Features

# %%
# creating polynomial features to capture non-linear realationships
poly = PolynomialFeatures(degree=2, include_bias=False)
poly_features = poly.fit_transform(df[['fixed acidity', 'volatile acidity', 'alcohol']])

# creating a new Dataframe for polynomial features
poly_feature_names = poly.get_feature_names_out(['fixed acidity', 'volatile acidity', 'alcohol'])
poly_df = pd.DataFrame(poly_features, columns=poly_feature_names)

# print head of the data
poly_df.head()
# Out:
#    fixed acidity  volatile acidity  alcohol  fixed acidity^2  \
# 0            7.4              0.70      9.4            54.76
# 1            7.8              0.88      9.8            60.84
# 2            7.8              0.76      9.8            60.84
# 3           11.2              0.28      9.8           125.44
# 4            7.4              0.70      9.4            54.76
#
#    fixed acidity volatile acidity  fixed acidity alcohol  volatile acidity^2  \
# 0                           5.180                  69.56              0.4900
# 1                           6.864                  76.44              0.7744
# 2                           5.928                  76.44              0.5776
# 3                           3.136                 109.76              0.0784
# 4                           5.180                  69.56              0.4900
#
#    volatile acidity alcohol  alcohol^2
# 0                     6.580      88.36
# 1                     8.624      96.04
# ...

# %% [markdown]
# ### 4. Feature Distribution Analysis

# %% [markdown]
# #### 4.1 Histograms/Density Plots

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality', 'Id', 'pH_alcohol',
#        'acidity_sulphates'],
#       dtype='object')

# %%
# visualizing the distribution of key numeric features like alcohol, pH, acidity
features_to_plot = ['alcohol', 'pH', 'fixed acidity', 'volatile acidity','residual sugar']

plt.figure(figsize=(15,8))
for i, feature in enumerate(features_to_plot, 1):
    plt.subplot(2, 3, i)  # Adjust subplot grid size based on the number of features
    sns.histplot(df[feature], kde=True, bins=20)
    plt.title(f'Distribution of {feature}')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### 4.2 Pairwise Feature Comparison

# %%
# using pariplots to explore realtionships between features
pairplot_features = ['alcohol', 'pH', 'fixed acidity', 'quality']
sns.pairplot(df[pairplot_features], hue='quality', diag_kind='kde')
plt.show()

# %% [markdown]
# #### 4.3 Target Variable Distribution (Quality)

# %%
# visualizing the distribution of the target variable (Quality)
plt.figure(figsize=(10,8))
sns.histplot(df['quality'], kde=True, bins=6)
plt.title('Distribution of Quality')
plt.xlabel("Wine Quality")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# #### 4.4 Feature vs. Target Analysis

# %%
# Using boxplots to analyze how features like alcohol, acidity, and residual sugar relate to wine quality
features_to_boxplot = ['alcohol', 'fixed acidity', 'residual sugar']

plt.figure(figsize=(15, 8))
for i, feature in enumerate(features_to_boxplot, 1):
    plt.subplot(2, 2, i)
    sns.boxplot(x='quality', y=feature, data=df)
    plt.title(f'{feature} vs Wine Quality')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Advanced Data Visualization

# %% [markdown]
# ### 1. Correlation Heatmap

# %%
# calculate the correlation matriz 
corr = df.corr()

# generate a heatmap for the correlation matrix 
plt.figure(figsize=(10, 8))
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Matrix of Wine Quality')
plt.show()

# %%
# extract the correlation of the target variable (quality)
corr_quality = corr['quality'].sort_values(ascending=False)

# print the correlations of the target variable (quality) with other features
print('Correlation of Wine Quality":')
print(corr_quality)
# Out:
# Correlation of Wine Quality":
# quality                 1.000000
# alcohol                 0.484866
# pH_alcohol              0.382603
# sulphates               0.257710
# acidity_sulphates       0.251131
# citric acid             0.240821
# fixed acidity           0.121970
# Id                      0.069708
# residual sugar          0.022002
# pH                     -0.052453
# free sulfur dioxide    -0.063260
# chlorides              -0.124085
# density                -0.175208
# total sulfur dioxide   -0.183339
# volatile acidity       -0.407394
# Name: quality, dtype: float64

# %% [markdown]
# ### 2. PairWise Feature Interaction

# %%
# 1. Create a pair plot to visualize relationships between selected features and quality
selected_features = ['alcohol', 'fixed acidity', 'volatile acidity', 'citric acid', 'quality']
sns.pairplot(df[selected_features], diag_kind='kde', hue='quality', palette='viridis')

plt.suptitle('Pairwise Feature Interaction with Quality', y=1.02)  # Adjust title position
plt.show()

# %%
# 2. Generate specific scatter plots for key feature pairs against quality
plt.figure(figsize=(12, 6))

# Alcohol vs. Quality
plt.subplot(2, 2, 1)
sns.scatterplot(data=df, x='alcohol', y='quality', color='blue')
plt.title('Alcohol vs. Quality')
plt.xlabel('Alcohol Content')
plt.ylabel('Quality')

# Fixed Acidity vs. Quality
plt.subplot(2, 2, 2)
sns.scatterplot(data=df, x='fixed acidity', y='quality', color='green')
plt.title('Fixed Acidity vs. Quality')
plt.xlabel('Fixed Acidity')
plt.ylabel('Quality')

# Volatile Acidity vs. Quality
plt.subplot(2, 2, 3)
sns.scatterplot(data=df, x='volatile acidity', y='quality', color='red')
plt.title('Volatile Acidity vs. Quality')
plt.xlabel('Volatile Acidity')
plt.ylabel('Quality')

# Citric Acid vs. Quality
plt.subplot(2, 2, 4)
sns.scatterplot(data=df, x='citric acid', y='quality', color='purple')
plt.title('Citric Acid vs. Quality')
plt.xlabel('Citric Acid')
plt.ylabel('Quality')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 3. Feature-Target Interaction

# %%
# Set the aesthetics for the plots
sns.set(style="whitegrid")

# %%
# 1. Boxplot for Alcohol vs. Quality
plt.figure(figsize=(12, 6))
plt.subplot(2, 2, 1)
sns.boxplot(data=df, x='quality', y='alcohol', palette='Blues')
plt.title('Alcohol Content by Quality Rating')
plt.xlabel('Quality Rating')
plt.ylabel('Alcohol Content')

# 2. Boxplot for Fixed Acidity vs. Quality
plt.subplot(2, 2, 2)
sns.boxplot(data=df, x='quality', y='fixed acidity', palette='Greens')
plt.title('Fixed Acidity by Quality Rating')
plt.xlabel('Quality Rating')
plt.ylabel('Fixed Acidity')

# 3. Violin Plot for Residual Sugar vs. Quality
plt.subplot(2, 2, 3)
sns.violinplot(data=df, x='quality', y='residual sugar', palette='Reds', inner='quartile')
plt.title('Residual Sugar Distribution by Quality Rating')
plt.xlabel('Quality Rating')
plt.ylabel('Residual Sugar')

# 4. Violin Plot for Sulphates vs. Quality
plt.subplot(2, 2, 4)
sns.violinplot(data=df, x='quality', y='sulphates', palette='Purples', inner='quartile')
plt.title('Sulphates Distribution by Quality Rating')
plt.xlabel('Quality Rating')
plt.ylabel('Sulphates')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 4. pH vs. Acidity Plot

# %%
# Set the aesthetics for the plots
sns.set(style="whitegrid")

# Create a figure with two subplots
plt.figure(figsize=(14, 6))

# 1. Scatter Plot for pH vs. Fixed Acidity
plt.subplot(1, 2, 1)
sns.regplot(data=df, x='pH', y='fixed acidity', scatter_kws={'alpha':0.5}, line_kws={'color':'blue'})
plt.title('pH vs. Fixed Acidity')
plt.xlabel('pH')
plt.ylabel('Fixed Acidity')

# 2. Scatter Plot for pH vs. Volatile Acidity
plt.subplot(1, 2, 2)
sns.regplot(data=df, x='pH', y='volatile acidity', scatter_kws={'alpha':0.5}, line_kws={'color':'red'})
plt.title('pH vs. Volatile Acidity')
plt.xlabel('pH')
plt.ylabel('Volatile Acidity')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 5. Alcohol vs. Quality Plot

# %%
# Create a figure with two subplots
plt.figure(figsize=(14, 6))

# 1. Boxplot for Alcohol vs. Quality
plt.subplot(1, 2, 1)
sns.boxplot(data=df, x='quality', y='alcohol', palette='Blues')
plt.title('Alcohol Content by Quality Rating')
plt.xlabel('Quality Rating')
plt.ylabel('Alcohol Content (%)')

# 2. Violin Plot for Alcohol vs. Quality
plt.subplot(1, 2, 2)
sns.violinplot(data=df, x='quality', y='alcohol', palette='Purples', inner='quartile')
plt.title('Alcohol Distribution by Quality Rating')
plt.xlabel('Quality Rating')
plt.ylabel('Alcohol Content (%)')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 6. Residual Sugar vs. Quality

# %%
# Create a boxplot for Residual Sugar vs. Quality
plt.figure(figsize=(10, 6))
sns.boxplot(data=df, x='quality', y='residual sugar', palette='Blues')
plt.title('Residual Sugar Content by Quality Rating')
plt.xlabel('Quality Rating')
plt.ylabel('Residual Sugar (g/dm³)')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 7. Sulfates vs. Quality

# %%
# Set the aesthetics for the plot
sns.set(style="whitegrid")

# Create a scatter plot for Sulfates vs. Quality
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='sulphates', y='quality', color='purple', alpha=0.6)
plt.title('Sulfates vs. Quality Rating')
plt.xlabel('Sulfates (g/dm³)')
plt.ylabel('Quality Rating')
plt.axhline(y=df['quality'].mean(), color='red', linestyle='--', label='Mean Quality')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 8. Sulfur Dioxide vs. Quality

# %%
# Create a regression plot for Free Sulfur Dioxide vs. Quality
plt.figure(figsize=(12, 6))

# Subplot for Free Sulfur Dioxide
plt.subplot(1, 2, 1)
sns.regplot(data=df, x='free sulfur dioxide', y='quality', scatter_kws={'alpha': 0.5}, line_kws={"color": "red"})
plt.title('Free Sulfur Dioxide vs. Quality Rating')
plt.xlabel('Free Sulfur Dioxide (mg/dm³)')
plt.ylabel('Quality Rating')

# Subplot for Total Sulfur Dioxide
plt.subplot(1, 2, 2)
sns.regplot(data=df, x='total sulfur dioxide', y='quality', scatter_kws={'alpha': 0.5}, line_kws={"color": "red"})
plt.title('Total Sulfur Dioxide vs. Quality Rating')
plt.xlabel('Total Sulfur Dioxide (mg/dm³)')
plt.ylabel('Quality Rating')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 9. Density vs. Alcohol

# %%
# using seaborn 
# Set the aesthetics for the plot
sns.set(style="whitegrid")

# Create a scatter plot for Density vs. Alcohol using Seaborn
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='alcohol', y='density', color='blue', alpha=0.6)
plt.title('Density vs. Alcohol Content (Seaborn)')
plt.xlabel('Alcohol Content (%)')
plt.ylabel('Density (g/cm³)')
plt.axhline(y=df['density'].mean(), color='red', linestyle='--', label='Mean Density')
plt.legend()

plt.tight_layout()
plt.show()

# %%
# using plotly 
# Create a scatter plot for Density vs. Alcohol using Plotly
fig = px.scatter(df, x='alcohol', y='density', 
                 title='Density vs. Alcohol Content (Plotly)',
                 labels={'alcohol': 'Alcohol Content (%)', 'density': 'Density (g/cm³)'},
                 opacity=0.6, color_discrete_sequence=['blue'])

# Add a mean density line
mean_density = df['density'].mean()
fig.add_hline(y=mean_density, line_dash="dash", line_color="red", annotation_text="Mean Density", annotation_position="bottom right")

# Show the figure
fig.show()

# %% [markdown]
# ### 10. Volatile Acidity vs. Quality

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality', 'Id', 'pH_alcohol',
#        'acidity_sulphates'],
#       dtype='object')

# %%
# Set the aesthetics for the plot
sns.set(style="whitegrid")

# Create a boxplot for volatile Acidity vs. Quality using Seaborn
plt.figure(figsize=(10, 6))
sns.boxplot(data=df, x='quality', y='volatile acidity', palette='coolwarm')
plt.title('Total Acidity vs. Wine Quality (Seaborn)')
plt.xlabel('Quality Rating')
plt.ylabel('Total Acidity (g/dm³)')

plt.tight_layout()
plt.show()

# %%
# Create a boxplot for Total Acidity vs. Quality using Plotly
fig = px.box(df, x='quality', y='volatile acidity', 
             title='Volatile Acidity vs. Wine Quality (Plotly)',
             labels={'quality': 'Quality Rating', 'volatile acidity': 'Volatile Acidity (g/dm³)'},
             color='quality', color_discrete_sequence=px.colors.qualitative.Plotly)

# Show the figure
fig.show()
